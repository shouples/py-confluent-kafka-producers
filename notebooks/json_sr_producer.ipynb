# %%
topic_name = "all_datatypes_json_sr"
schema_file_path = "./schemas/jsonschema_all_datatypes.json"

# %%
import json


class Config:
    def __init__(self):
        config = json.loads(open("../config.json").read())
        self.kc_endpoint = config["kc_endpoint"]
        self.kc_api_key = config["kc_api_key"]
        self.kc_api_secret = config["kc_api_secret"]
        self.sr_endpoint = config["sr_endpoint"]
        self.sr_api_key = config["sr_api_key"]
        self.sr_api_secret = config["sr_api_secret"]


c = Config()

# %%
from confluent_kafka import Producer
from confluent_kafka.schema_registry import SchemaRegistryClient
from confluent_kafka.schema_registry.json_schema import JSONSerializer
from confluent_kafka.serialization import MessageField, SerializationContext

import datagen

# serializer setup
sr_client = SchemaRegistryClient(
    {
        "url": c.sr_endpoint,
        "basic.auth.user.info": f"{c.sr_api_key}:{c.sr_api_secret}",
    }
)
serializer = JSONSerializer(
    schema_registry_client=sr_client,
    schema_str=open(schema_file_path).read(),
    to_dict=lambda x, ctx: x,  # I still don't know why this is necessary.
)

conf = {
    "bootstrap.servers": c.kc_endpoint,
    "security.protocol": "SASL_SSL",
    "sasl.mechanisms": "PLAIN",
    "sasl.username": c.kc_api_key,
    "sasl.password": c.kc_api_secret,
}
producer = Producer(conf)


def produce_messages(num_messages: int = 5):
    messages_sent = []

    for _ in range(num_messages):
        key = datagen.generate_key()
        value = datagen.generate_jsonschema_all_datatypes()
        headers = datagen.generate_headers()
        serialized_value = serializer(
            value, SerializationContext(topic_name, MessageField.VALUE)
        )
        producer.produce(
            topic_name,
            key=key,
            value=serialized_value,
            headers=headers,
            on_delivery=lambda err, msg: print(f"{err=}") if err else None,
        )
        messages_sent.append(
            {
                "key": key,
                "value": value,
                "headers": headers,
                "topic": topic_name,
                "serialized_value": serialized_value,
            }
        )
    producer.flush()

    return messages_sent


messages = produce_messages(5)
# Out:
# msg=<cimpl.Message object at 0x10b195840>
# msg=<cimpl.Message object at 0x10b0cea40>
# msg=<cimpl.Message object at 0x10b0cea40>
# msg=<cimpl.Message object at 0x10b0cea40>
# msg=<cimpl.Message object at 0x10b0cea40>

# %%
len(json.dumps(messages[0])), messages[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 len(json.dumps(messages[0])), messages[0]
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/json/__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/json/encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/json/encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type bytes is not JSON serializable
# %5|1719460906.766|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Timed out MetadataRequest in flight (after 1045086ms, timeout #0)
# %4|1719460906.766|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1719460906.766|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: 1 request(s) timed out: disconnect (after 6569951ms in state UP)
# %3|1719460906.781|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Failed to resolve 'b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092': nodename nor servname provided, or not known (after 15ms in state CONNECT)
# %6|1719461661.369|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 738775ms in state UP)
# %6|1719461661.581|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 739028ms in state UP)
# %6|1719461661.883|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 739281ms in state UP)
# %4|1719461662.184|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 739574ms in state UP)
# %6|1719461662.646|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 740083ms in state UP, 1 identical error(s) suppressed)
# %4|1719461663.146|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 740642ms in state UP)
# %6|1719461663.639|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 741201ms in state UP, 1 identical error(s) suppressed)
# %4|1719461664.215|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 741459ms in state UP)
# %6|1719461664.810|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 742304ms in state UP)
# %4|1719461665.643|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 743171ms in state UP)
# %6|1719462561.441|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 894109ms in state UP, 1 identical error(s) suppressed)
# %6|1719462561.836|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 893422ms in state UP, 1 identical error(s) suppressed)
# %6|1719462562.096|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 1639502ms in state UP)
# %4|1719462562.293|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 892483ms in state UP, 1 identical error(s) suppressed)
# %6|1719462562.663|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 896801ms in state UP, 1 identical error(s) suppressed)
# %6|1719462562.951|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 896429ms in state UP, 1 identical error(s) suppressed)
# %4|1719462563.213|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 897609ms in state UP, 1 identical error(s) suppressed)
# %6|1719462563.473|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 898266ms in state UP, 1 identical error(s) suppressed)
# %6|1719462563.960|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 898264ms in state UP, 1 identical error(s) suppressed)
# %5|1719463484.674|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Timed out MetadataRequest in flight (after 60109ms, timeout #0)
# %4|1719463484.674|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1719463484.675|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: 1 request(s) timed out: disconnect (after 912108ms in state UP)
# %3|1719463485.686|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Failed to resolve 'b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092': nodename nor servname provided, or not known (after 2ms in state CONNECT)
# %4|1719463485.686|METADATA|rdkafka#producer-1| [thrd:main]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Metadata request failed: periodic topic and broker list refresh: Local: Host resolution failure (0ms): Permanent
# %5|1719463545.064|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Timed out MetadataRequest in flight (after 60388ms, timeout #0)
# %5|1719463545.064|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Timed out MetadataRequest in flight (after 60118ms, timeout #1)
# %4|1719463545.064|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Timed out 2 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1719463545.065|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: 2 request(s) timed out: disconnect (after 979718ms in state UP)
# %3|1719463545.190|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Failed to resolve 'b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT)
# %4|1719463545.190|METADATA|rdkafka#producer-1| [thrd:main]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Metadata request failed: broker down: Local: Host resolution failure (0ms): Permanent
# %4|1719463545.190|METADATA|rdkafka#producer-1| [thrd:main]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Metadata request failed: refresh unavailable topics: Local: Host resolution failure (0ms): Permanent
# %3|1719463546.198|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Failed to resolve 'b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT, 1 identical error(s) suppressed)
# %4|1719463546.198|METADATA|rdkafka#producer-1| [thrd:main]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Metadata request failed: refresh unavailable topics: Local: Host resolution failure (0ms): Permanent
# %5|1719464563.537|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Timed out MetadataRequest in flight (after 1018472ms, timeout #0)
# %5|1719464563.538|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Timed out MetadataRequest in flight (after 1018199ms, timeout #1)
# %5|1719464563.538|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Timed out MetadataRequest in flight (after 1017193ms, timeout #2)
# %4|1719464563.538|REQTMOUT|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Timed out 3 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1719464563.538|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: 3 request(s) timed out: disconnect (after 2893933ms in state UP)
# %3|1719464563.651|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Failed to resolve 'b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092': nodename nor servname provided, or not known (after 1ms in state CONNECT)
# %4|1719464563.651|METADATA|rdkafka#producer-1| [thrd:main]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Metadata request failed: broker down: Local: Host resolution failure (0ms): Permanent
# %4|1719464563.651|METADATA|rdkafka#producer-1| [thrd:main]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Metadata request failed: refresh unavailable topics: Local: Host resolution failure (0ms): Permanent
# %4|1719464564.601|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 1998286ms in state UP, 1 identical error(s) suppressed)
# %6|1719464564.687|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 1997407ms in state UP, 1 identical error(s) suppressed)
# %6|1719464564.738|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 1996808ms in state UP, 1 identical error(s) suppressed)
# %6|1719464564.997|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 2001127ms in state UP, 1 identical error(s) suppressed)
# %6|1719464565.259|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 2001289ms in state UP, 1 identical error(s) suppressed)
# %6|1719464565.479|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 2000889ms in state UP, 1 identical error(s) suppressed)
# %4|1719464565.616|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 2895599ms in state UP, 1 identical error(s) suppressed)
# %6|1719464565.766|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 2001142ms in state UP, 1 identical error(s) suppressed)
# %6|1719464565.922|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 3643165ms in state UP)
# %6|1719465261.669|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 695786ms in state UP, 1 identical error(s) suppressed)
# %6|1719465261.879|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 695869ms in state UP, 1 identical error(s) suppressed)
# %6|1719465262.227|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 695870ms in state UP, 1 identical error(s) suppressed)
# %4|1719465262.580|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 696318ms in state UP, 1 identical error(s) suppressed)
# %6|1719465262.926|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 696807ms in state UP, 1 identical error(s) suppressed)
# %6|1719465263.312|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 697483ms in state UP)
# %6|1719465263.599|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 697419ms in state UP, 1 identical error(s) suppressed)
# %6|1719465263.809|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 697778ms in state UP, 1 identical error(s) suppressed)
# %6|1719465264.058|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 698288ms in state UP, 1 identical error(s) suppressed)
# %6|1719466161.623|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 897614ms in state UP, 1 identical error(s) suppressed)
# %6|1719466161.748|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 897306ms in state UP, 1 identical error(s) suppressed)
# %6|1719466161.914|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 896017ms in state UP, 1 identical error(s) suppressed)
# %6|1719466162.098|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 897376ms in state UP, 1 identical error(s) suppressed)
# %4|1719466162.306|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 1595859ms in state UP, 1 identical error(s) suppressed)
# %6|1719466162.602|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 897298ms in state UP, 1 identical error(s) suppressed)
# %6|1719466163.106|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 898754ms in state UP, 1 identical error(s) suppressed)
# %4|1719466163.415|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 896303ms in state UP, 1 identical error(s) suppressed)
# %6|1719466163.648|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 897170ms in state UP, 1 identical error(s) suppressed)
# %6|1719466163.811|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 899632ms in state UP, 1 identical error(s) suppressed)
# %6|1719467961.568|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 1797555ms in state UP, 1 identical error(s) suppressed)
# %6|1719467961.673|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 1797324ms in state UP, 1 identical error(s) suppressed)
# %6|1719467961.894|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 1798174ms in state UP, 1 identical error(s) suppressed)
# %4|1719467962.091|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 1797432ms in state UP, 1 identical error(s) suppressed)
# %6|1719467962.226|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 1798218ms in state UP, 1 identical error(s) suppressed)
# %6|1719467962.471|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 1796987ms in state UP, 1 identical error(s) suppressed)
# %6|1719467963.024|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 1797608ms in state UP, 1 identical error(s) suppressed)
# %4|1719467963.443|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 1799617ms in state UP, 1 identical error(s) suppressed)
# %6|1719467963.782|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 1797865ms in state UP, 1 identical error(s) suppressed)
# %6|1719467964.033|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 1799779ms in state UP, 1 identical error(s) suppressed)
# %6|1719468861.894|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 897271ms in state UP, 1 identical error(s) suppressed)
# %6|1719468861.995|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 897712ms in state UP, 1 identical error(s) suppressed)
# %6|1719468862.132|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 895142ms in state UP, 1 identical error(s) suppressed)
# %4|1719468862.338|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 898292ms in state UP, 1 identical error(s) suppressed)
# %6|1719468862.469|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 898187ms in state UP, 1 identical error(s) suppressed)
# %6|1719468862.781|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 897449ms in state UP, 1 identical error(s) suppressed)
# %4|1719468863.323|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 895467ms in state UP, 1 identical error(s) suppressed)
# %6|1719468863.658|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 897511ms in state UP, 1 identical error(s) suppressed)
# %6|1719468863.903|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 899550ms in state UP, 1 identical error(s) suppressed)
# %6|1719468864.214|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 900312ms in state UP, 1 identical error(s) suppressed)
# %6|1719469746.658|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 880907ms in state UP, 1 identical error(s) suppressed)
# %6|1719469746.762|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 879585ms in state UP, 1 identical error(s) suppressed)
# %6|1719469746.930|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 882742ms in state UP, 1 identical error(s) suppressed)
# %4|1719469747.068|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 881988ms in state UP, 1 identical error(s) suppressed)
# %6|1719469747.232|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 880785ms in state UP, 1 identical error(s) suppressed)
# %6|1719469747.590|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 879823ms in state UP, 1 identical error(s) suppressed)
# %6|1719469747.930|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 883676ms in state UP, 1 identical error(s) suppressed)
# %4|1719469748.210|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 883592ms in state UP, 1 identical error(s) suppressed)
# %6|1719469748.438|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 883831ms in state UP, 1 identical error(s) suppressed)
# %6|1719469748.742|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 884135ms in state UP, 1 identical error(s) suppressed)
# %6|1719470681.430|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 929506ms in state UP, 1 identical error(s) suppressed)
# %6|1719470681.767|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 929017ms in state UP, 1 identical error(s) suppressed)
# %4|1719470681.993|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 933363ms in state UP, 1 identical error(s) suppressed)
# %6|1719470682.252|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 933481ms in state UP, 1 identical error(s) suppressed)
# %6|1719470682.474|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 933148ms in state UP, 1 identical error(s) suppressed)
# %6|1719470682.955|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 934183ms in state UP, 1 identical error(s) suppressed)
# %6|1719470683.308|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 932977ms in state UP, 1 identical error(s) suppressed)
# %4|1719470683.321|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 932340ms in state UP, 1 identical error(s) suppressed)
# %4|1719470684.080|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 934895ms in state UP, 1 identical error(s) suppressed)
# %4|1719470685.205|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 935344ms in state UP, 1 identical error(s) suppressed)
# %6|1719470686.480|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstra]: sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstrap: Disconnected (after 9764041ms in state UP, 1 identical error(s) suppressed)
# %6|1719471562.459|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 875894ms in state UP, 1 identical error(s) suppressed)
# %6|1719471562.695|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 877430ms in state UP, 1 identical error(s) suppressed)
# %6|1719471562.927|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 875214ms in state UP, 1 identical error(s) suppressed)
# %4|1719471563.066|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 873016ms in state UP, 1 identical error(s) suppressed)
# %6|1719471563.204|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 873164ms in state UP, 1 identical error(s) suppressed)
# %6|1719471563.686|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 874794ms in state UP, 1 identical error(s) suppressed)
# %6|1719471564.057|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 871475ms in state UP, 1 identical error(s) suppressed)
# %6|1719471564.579|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 879148ms in state UP, 1 identical error(s) suppressed)
# %4|1719471565.153|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 872572ms in state UP, 1 identical error(s) suppressed)
# %6|1719471565.544|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 877766ms in state UP, 1 identical error(s) suppressed)
# %6|1719472461.985|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 896713ms in state UP, 1 identical error(s) suppressed)
# %6|1719472462.230|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 896662ms in state UP, 1 identical error(s) suppressed)
# %6|1719472462.453|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 895349ms in state UP, 1 identical error(s) suppressed)
# %6|1719472462.701|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 896758ms in state UP, 1 identical error(s) suppressed)
# %4|1719472462.960|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 897366ms in state UP, 1 identical error(s) suppressed)
# %6|1719472463.266|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 896512ms in state UP, 1 identical error(s) suppressed)
# %6|1719472463.470|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 897206ms in state UP, 1 identical error(s) suppressed)
# %4|1719472465.599|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 900096ms in state UP, 1 identical error(s) suppressed)
# %6|1719473346.122|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 881706ms in state UP, 1 identical error(s) suppressed)
# %6|1719473346.297|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 879110ms in state UP, 1 identical error(s) suppressed)
# %6|1719473346.450|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1]: sasl_ssl://b1-pkc-619z3.us-east1.gcp.confluent.cloud:9092/1: Disconnected (after 879082ms in state UP, 1 identical error(s) suppressed)
# %6|1719473346.581|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 882618ms in state UP, 1 identical error(s) suppressed)
# %6|1719473346.754|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 1779297ms in state UP, 1 identical error(s) suppressed)
# %4|1719473347.147|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 880894ms in state UP, 1 identical error(s) suppressed)
# %6|1719473347.501|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 883494ms in state UP, 1 identical error(s) suppressed)
# %6|1719473347.794|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10]: sasl_ssl://b10-pkc-619z3.us-east1.gcp.confluent.cloud:9092/10: Disconnected (after 883943ms in state UP, 1 identical error(s) suppressed)
# %4|1719473348.042|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 881492ms in state UP, 1 identical error(s) suppressed)
# %6|1719473348.186|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 1781698ms in state UP, 1 identical error(s) suppressed)
# %6|1719475147.527|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 1797681ms in state UP, 1 identical error(s) suppressed)
# %6|1719475147.613|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstra]: sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstrap: Disconnected (after 4452529ms in state UP, 1 identical error(s) suppressed)
# %6|1719476080.458|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 931242ms in state UP, 1 identical error(s) suppressed)
# %6|1719476080.603|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 931520ms in state UP, 1 identical error(s) suppressed)
# %6|1719476080.843|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 931601ms in state UP)
# %6|1719476080.990|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstra]: sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstrap: Disconnected (after 931756ms in state UP, 1 identical error(s) suppressed)
# %6|1719476961.112|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 877307ms in state UP, 1 identical error(s) suppressed)
# %6|1719476961.283|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 878763ms in state UP, 1 identical error(s) suppressed)
# %6|1719476961.372|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 878761ms in state UP, 1 identical error(s) suppressed)
# %6|1719476961.492|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 879065ms in state UP, 1 identical error(s) suppressed)
# %6|1719476961.643|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 879193ms in state UP, 1 identical error(s) suppressed)
# %6|1719476961.781|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 879157ms in state UP, 1 identical error(s) suppressed)
# %4|1719476961.972|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstra]: sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstrap: Disconnected (after 879393ms in state UP, 1 identical error(s) suppressed)
# %6|1719477861.406|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 898576ms in state UP, 1 identical error(s) suppressed)
# %6|1719477861.646|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 898517ms in state UP, 1 identical error(s) suppressed)
# %6|1719477861.778|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 898762ms in state UP, 1 identical error(s) suppressed)
# %6|1719477861.895|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 898266ms in state UP, 1 identical error(s) suppressed)
# %4|1719477862.299|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 899487ms in state UP, 1 identical error(s) suppressed)
# %6|1719477862.773|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 899970ms in state UP, 1 identical error(s) suppressed)
# %6|1719477862.978|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 899867ms in state UP, 1 identical error(s) suppressed)
# %6|1719477863.160|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstra]: sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstrap: Disconnected (after 899867ms in state UP, 1 identical error(s) suppressed)
# %6|1719478762.584|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 898910ms in state UP, 1 identical error(s) suppressed)
# %6|1719478762.699|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 899267ms in state UP, 1 identical error(s) suppressed)
# %6|1719478762.862|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 897782ms in state UP)
# %6|1719478763.009|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 899336ms in state UP, 1 identical error(s) suppressed)
# %6|1719478763.203|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 898953ms in state UP, 1 identical error(s) suppressed)
# %6|1719478763.714|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 898937ms in state UP, 1 identical error(s) suppressed)
# %4|1719478764.071|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 900551ms in state UP, 1 identical error(s) suppressed)
# %6|1719478764.343|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 899694ms in state UP, 1 identical error(s) suppressed)
# %6|1719478764.655|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 901135ms in state UP, 1 identical error(s) suppressed)
# %6|1719478765.192|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstra]: sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstrap: Disconnected (after 900317ms in state UP, 1 identical error(s) suppressed)
# %6|1719479647.918|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 882725ms in state UP, 1 identical error(s) suppressed)
# %6|1719479648.072|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 882471ms in state UP, 1 identical error(s) suppressed)
# %6|1719479648.285|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 881785ms in state UP, 1 identical error(s) suppressed)
# %6|1719479648.417|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 882517ms in state UP, 1 identical error(s) suppressed)
# %4|1719479648.613|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 883007ms in state UP, 1 identical error(s) suppressed)
# %6|1719479649.121|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 881759ms in state UP, 1 identical error(s) suppressed)
# %6|1719479649.383|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 884077ms in state UP, 1 identical error(s) suppressed)
# %4|1719479649.620|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 882570ms in state UP, 1 identical error(s) suppressed)
# %6|1719479649.805|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 884878ms in state UP, 1 identical error(s) suppressed)
# %6|1719479649.942|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstra]: sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstrap: Disconnected (after 882078ms in state UP, 1 identical error(s) suppressed)
# %6|1719480547.744|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 897537ms in state UP, 1 identical error(s) suppressed)
# %6|1719480547.831|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 897471ms in state UP, 1 identical error(s) suppressed)
# ...
# %4|1719488663.549|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 879889ms in state UP, 1 identical error(s) suppressed)
# %6|1719488663.897|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstra]: sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstrap: Disconnected (after 4498371ms in state UP, 1 identical error(s) suppressed)
# %6|1719489580.784|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 916610ms in state UP, 1 identical error(s) suppressed)
# %6|1719489580.933|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 916642ms in state UP, 1 identical error(s) suppressed)
# %6|1719489581.147|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 917195ms in state UP, 1 identical error(s) suppressed)
# %4|1719489581.372|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 917686ms in state UP, 1 identical error(s) suppressed)
# %6|1719489581.691|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 918004ms in state UP, 1 identical error(s) suppressed)
# %6|1719489581.850|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 916974ms in state UP, 1 identical error(s) suppressed)
# %6|1719489582.063|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 915758ms in state UP, 1 identical error(s) suppressed)
# %6|1719489582.256|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 917002ms in state UP, 1 identical error(s) suppressed)
# %4|1719489582.441|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 918120ms in state UP, 1 identical error(s) suppressed)
# %6|1719489582.657|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 916866ms in state UP, 1 identical error(s) suppressed)
# %6|1719490481.035|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 896975ms in state UP, 1 identical error(s) suppressed)
# %6|1719490481.228|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 896837ms in state UP, 1 identical error(s) suppressed)
# %6|1719490481.541|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 898785ms in state UP, 1 identical error(s) suppressed)
# %6|1719490481.667|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 898711ms in state UP, 1 identical error(s) suppressed)
# %6|1719490482.007|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 898304ms in state UP, 1 identical error(s) suppressed)
# %4|1719490482.630|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 899619ms in state UP, 1 identical error(s) suppressed)
# %6|1719490483.001|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 900430ms in state UP, 1 identical error(s) suppressed)
# %6|1719490483.264|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 900526ms in state UP, 1 identical error(s) suppressed)
# %6|1719490483.612|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 900351ms in state UP, 1 identical error(s) suppressed)
# %4|1719490483.749|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 899015ms in state UP, 1 identical error(s) suppressed)
# %6|1719491362.105|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 878153ms in state UP, 1 identical error(s) suppressed)
# %6|1719491362.233|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 878268ms in state UP, 1 identical error(s) suppressed)
# %6|1719491362.345|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 878397ms in state UP, 1 identical error(s) suppressed)
# %6|1719491362.510|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 877601ms in state UP, 1 identical error(s) suppressed)
# %6|1719491362.760|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 878306ms in state UP, 1 identical error(s) suppressed)
# %4|1719491363.108|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 879183ms in state UP, 1 identical error(s) suppressed)
# %6|1719491363.369|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 879012ms in state UP, 1 identical error(s) suppressed)
# %6|1719491363.596|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 878582ms in state UP, 1 identical error(s) suppressed)
# %6|1719491363.795|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 880152ms in state UP, 1 identical error(s) suppressed)
# %6|1719491363.951|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 878651ms in state UP, 1 identical error(s) suppressed)
# %6|1719492260.748|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 895103ms in state UP, 1 identical error(s) suppressed)
# %6|1719492260.867|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 896176ms in state UP, 1 identical error(s) suppressed)
# %6|1719492260.996|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 896821ms in state UP, 1 identical error(s) suppressed)
# %6|1719492261.069|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 896984ms in state UP, 1 identical error(s) suppressed)
# %6|1719492261.234|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 897321ms in state UP, 1 identical error(s) suppressed)
# %4|1719492261.675|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 895652ms in state UP, 1 identical error(s) suppressed)
# %6|1719492262.035|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 897367ms in state UP, 1 identical error(s) suppressed)
# %6|1719492262.273|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 897995ms in state UP, 1 identical error(s) suppressed)
# %6|1719492262.478|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 898302ms in state UP, 1 identical error(s) suppressed)
# %6|1719492262.651|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 897289ms in state UP, 1 identical error(s) suppressed)
# %6|1719493161.087|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 897329ms in state UP, 1 identical error(s) suppressed)
# %6|1719493161.236|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 898328ms in state UP, 1 identical error(s) suppressed)
# %4|1719493161.627|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 898706ms in state UP, 1 identical error(s) suppressed)
# %6|1719493161.841|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 898770ms in state UP, 1 identical error(s) suppressed)
# %6|1719493161.996|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 899335ms in state UP, 1 identical error(s) suppressed)
# %6|1719493162.152|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 898687ms in state UP, 1 identical error(s) suppressed)
# %4|1719493162.504|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 899375ms in state UP, 1 identical error(s) suppressed)
# %6|1719493162.775|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 900164ms in state UP, 1 identical error(s) suppressed)
# %6|1719493163.165|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 899458ms in state UP, 1 identical error(s) suppressed)
# %4|1719493163.582|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 900808ms in state UP, 1 identical error(s) suppressed)
# %6|1719493163.946|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstra]: sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstrap: Disconnected (after 4497116ms in state UP, 1 identical error(s) suppressed)
# %6|1719493806.674|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4]: sasl_ssl://b4-pkc-619z3.us-east1.gcp.confluent.cloud:9092/4: Disconnected (after 641361ms in state UP, 1 identical error(s) suppressed)
# %6|1719493806.746|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11]: sasl_ssl://b11-pkc-619z3.us-east1.gcp.confluent.cloud:9092/11: Disconnected (after 643032ms in state UP, 1 identical error(s) suppressed)
# %6|1719493806.919|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5]: sasl_ssl://b5-pkc-619z3.us-east1.gcp.confluent.cloud:9092/5: Disconnected (after 642962ms in state UP, 1 identical error(s) suppressed)
# %6|1719493807.243|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0]: sasl_ssl://b0-pkc-619z3.us-east1.gcp.confluent.cloud:9092/0: Disconnected (after 641478ms in state UP, 1 identical error(s) suppressed)
# %6|1719493807.493|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3]: sasl_ssl://b3-pkc-619z3.us-east1.gcp.confluent.cloud:9092/3: Disconnected (after 641240ms in state UP, 1 identical error(s) suppressed)
# %6|1719493807.672|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6]: sasl_ssl://b6-pkc-619z3.us-east1.gcp.confluent.cloud:9092/6: Disconnected (after 643230ms in state UP, 1 identical error(s) suppressed)
# %6|1719493807.853|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2]: sasl_ssl://b2-pkc-619z3.us-east1.gcp.confluent.cloud:9092/2: Disconnected (after 642927ms in state UP, 1 identical error(s) suppressed)
# %6|1719493808.079|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8]: sasl_ssl://b8-pkc-619z3.us-east1.gcp.confluent.cloud:9092/8: Disconnected (after 644371ms in state UP, 1 identical error(s) suppressed)
# %4|1719493808.321|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9]: sasl_ssl://b9-pkc-619z3.us-east1.gcp.confluent.cloud:9092/9: Disconnected (after 643879ms in state UP, 1 identical error(s) suppressed)
# %6|1719493808.538|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7]: sasl_ssl://b7-pkc-619z3.us-east1.gcp.confluent.cloud:9092/7: Disconnected (after 643759ms in state UP, 1 identical error(s) suppressed)
# %6|1719493808.929|FAIL|rdkafka#producer-1| [thrd:sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstra]: sasl_ssl://pkc-619z3.us-east1.gcp.confluent.cloud:9092/bootstrap: Disconnected (after 642272ms in state UP, 1 identical error(s) suppressed)
